# %% [markdown]
# #### Webscraping for creating Mindmaps
# - Lets see if we can find terms/keywords related to a topic, and possibly find an ordering of how they should be learned
# - Use these lists words as RAG for the llm, as the roadmap
#
# #### Ideas
# 1. Scraping Wikipedia
#     - There is a related API, but it is usually too deep
#     - Extract keywords and links from wiki page,
#         - Possibly go a level down, and see how many link back to our current page

# %%
import requests
from bs4 import BeautifulSoup

# %%
# API docs: https://en.wikipedia.org/api/rest_v1/
BASE_URL = "https://en.wikipedia.org/api/rest_v1"

# %%
res = requests.get(BASE_URL + "/page/html/computer_science")
html = res.text
print(len(html), html[:300])
# Out:
# 477772 <!DOCTYPE html>
# <html prefix="dc: http://purl.org/dc/terms/ mw: http://mediawiki.org/rdf/" about="https://en.wikipedia.org/wiki/Special:Redirect/revision/1254992720"><head prefix="mwr: https://en.wikipedia.org/wiki/Special:Redirect/"><meta property="mw:TimeUuid" content="2acbc670-99b6-11ef-a775-236a

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
for x in soup.find_all('a'):
    href = x['href']
    rel = x.get('rel', [])
    text = x.text
    print(href, text, rel)
    if href.startswith("/wiki/") or 'mw:WikiLink' in rel:
        print(text, href)
# Out:
# ./Computer_science_(disambiguation) Computer science (disambiguation) ['mw:WikiLink']
# Computer science (disambiguation) ./Computer_science_(disambiguation)
# ./File:Lambda_calculus-Church_numerals.png  []
# ./Programming_language_theory Programming language theory ['mw:WikiLink']
# Programming language theory ./Programming_language_theory
# ./File:Sorting_quicksort_anim.gif  []
# ./Computational_complexity_theory Computational complexity theory ['mw:WikiLink']
# Computational complexity theory ./Computational_complexity_theory
# ./File:Activemarker2.PNG  []
# ./Artificial_intelligence Artificial intelligence ['mw:WikiLink']
# Artificial intelligence ./Artificial_intelligence
# ./File:Half_Adder.svg  []
# ./Computer_architecture Computer architecture ['mw:WikiLink']
# Computer architecture ./Computer_architecture
# ./Computer_science Computer science ['mw:WikiLink']
# Computer science ./Computer_science
# ./File:Flowchart_structured_programming.svg  []
# ./History_of_computer_science History ['mw:WikiLink']
# History ./History_of_computer_science
# ./Outline_of_computer_science Outline ['mw:WikiLink']
# Outline ./Outline_of_computer_science
# ./Glossary_of_computer_science Glossary ['mw:WikiLink']
# Glossary ./Glossary_of_computer_science
# ./Category:Computer_science Category ['mw:WikiLink']
# Category ./Category:Computer_science
# ./Template:TopicTOC-Computer_science v ['mw:WikiLink']
# v ./Template:TopicTOC-Computer_science
# ./Template_talk:TopicTOC-Computer_science t ['mw:WikiLink']
# t ./Template_talk:TopicTOC-Computer_science
# ./Special:EditPage/Template:TopicTOC-Computer_science e ['mw:WikiLink']
# e ./Special:EditPage/Template:TopicTOC-Computer_science
# ./Computation computation ['mw:WikiLink']
# computation ./Computation
# ./Information information ['mw:WikiLink']
# information ./Information
# ./Automation automation ['mw:WikiLink']
# automation ./Automation
# ./Computer_science#cite_note-YorkDefinition-1 [1] []
# ./Computer_science#cite_note-MITAutomated-2 [2] []
# ./Computer_science#cite_note-DenningAutomated-3 [3] []
# ./Theoretical_computer_science theoretical disciplines ['mw:WikiLink']
# theoretical disciplines ./Theoretical_computer_science
# ./Algorithm algorithms ['mw:WikiLink']
# algorithms ./Algorithm
# ./Theory_of_computation theory of computation ['mw:WikiLink']
# theory of computation ./Theory_of_computation
# ./Information_theory information theory ['mw:WikiLink']
# information theory ./Information_theory
# ./Applied_science applied disciplines ['mw:WikiLink']
# applied disciplines ./Applied_science
# ./Computer_architecture hardware ['mw:WikiLink']
# hardware ./Computer_architecture
# ./Software_engineering software ['mw:WikiLink']
# software ./Software_engineering
# ./Computer_science#cite_note-4 [4] []
# ./Computer_science#cite_note-5 [5] []
# ./Computer_science#cite_note-6 [6] []
# ./Data_structure data structures ['mw:WikiLink']
# data structures ./Data_structure
# ./Computer_science#cite_note-7 [7] []
# ./Models_of_computation models of computation ['mw:WikiLink']
# models of computation ./Models_of_computation
# ./Computational_problem problems ['mw:WikiLink']
# problems ./Computational_problem
# ./Cryptography cryptography ['mw:WikiLink']
# cryptography ./Cryptography
# ./Computer_security computer security ['mw:WikiLink']
# computer security ./Computer_security
# ./Security_vulnerabilities security vulnerabilities ['mw:WikiLink']
# security vulnerabilities ./Security_vulnerabilities
# ./Computer_graphics_(computer_science) Computer graphics ['mw:WikiLink']
# Computer graphics ./Computer_graphics_(computer_science)
# ./Computational_geometry computational geometry ['mw:WikiLink']
# computational geometry ./Computational_geometry
# ./Programming_language_theory Programming language theory ['mw:WikiLink']
# Programming language theory ./Programming_language_theory
# ./Database database ['mw:WikiLink']
# database ./Database
# ./Human–computer_interaction Human–computer interaction ['mw:WikiLink']
# Human–computer interaction ./Human–computer_interaction
# ./Operating_system operating systems ['mw:WikiLink']
# operating systems ./Operating_system
# ./Computer_network networks ['mw:WikiLink']
# networks ./Computer_network
# ./Embedded_system embedded systems ['mw:WikiLink']
# embedded systems ./Embedded_system
# ./Complex_system complex systems ['mw:WikiLink']
# complex systems ./Complex_system
# ./Artificial_intelligence Artificial intelligence ['mw:WikiLink']
# Artificial intelligence ./Artificial_intelligence
# ./Machine_learning machine learning ['mw:WikiLink']
# machine learning ./Machine_learning
# ./Automated_planning_and_scheduling planning ['mw:WikiLink']
# planning ./Automated_planning_and_scheduling
# ./Computer_vision computer vision ['mw:WikiLink']
# computer vision ./Computer_vision
# ./Natural_language_processing natural language processing ['mw:WikiLink']
# natural language processing ./Natural_language_processing
# ./Computer_science#cite_note-MITAutomated-2 [2] []
# ./Computer_science#cite_note-8 [8] []
# ./Computer_science#cite_note-DenningAutomated-3 [3] []
# ./Computer_science#cite_note-9 [9] []
# ./Computer_science#cite_note-10 [10] []
# ./Turing_Award Turing Award ['mw:WikiLink']
# Turing Award ./Turing_Award
# ./Computer_science#cite_note-11 [11] []
# ./Computer_science#cite_note-12 [12] []
# ./History_of_computer_science History of computer science ['mw:WikiLink']
# History of computer science ./History_of_computer_science
# ./History_of_computing History of computing ['mw:WikiLink']
# History of computing ./History_of_computing
# ./File:Glen_Beck_and_Betty_Snyder_program_the_ENIAC_in_building_328_at_the_Ballistic_Research_Laboratory.jpg  []
# ./Computer_hardware Hardware ['mw:WikiLink']
# Hardware ./Computer_hardware
# ./Timeline_of_computing_hardware_before_1950  Hardware before 1960 ['mw:WikiLink']
#  Hardware before 1960 ./Timeline_of_computing_hardware_before_1950
# ./History_of_computing_hardware_(1960s–present) Hardware 1960s to present ['mw:WikiLink']
# Hardware 1960s to present ./History_of_computing_hardware_(1960s–present)
# ./Software Software ['mw:WikiLink']
# Software ./Software
# ./History_of_software Software ['mw:WikiLink']
# Software ./History_of_software
# ./History_of_software_configuration_management Software configuration management ['mw:WikiLink']
# Software configuration management ./History_of_software_configuration_management
# ./History_of_Unix Unix ['mw:WikiLink']
# Unix ./History_of_Unix
# ./History_of_free_and_open-source_software Free software and open-source software ['mw:WikiLink']
# Free software and open-source software ./History_of_free_and_open-source_software
# ./Computer_science Computer science ['mw:WikiLink']
# Computer science ./Computer_science
# ./History_of_artificial_intelligence Artificial intelligence ['mw:WikiLink']
# Artificial intelligence ./History_of_artificial_intelligence
# ./History_of_compiler_construction Compiler construction ['mw:WikiLink']
# Compiler construction ./History_of_compiler_construction
# ./History_of_computer_science Early computer science ['mw:WikiLink']
# Early computer science ./History_of_computer_science
# ./History_of_operating_systems Operating systems ['mw:WikiLink']
# Operating systems ./History_of_operating_systems
# ./History_of_programming_languages Programming languages ['mw:WikiLink']
# Programming languages ./History_of_programming_languages
# ./List_of_pioneers_in_computer_science Prominent pioneers ['mw:WikiLink']
# Prominent pioneers ./List_of_pioneers_in_computer_science
# ./History_of_software_engineering Software engineering ['mw:WikiLink']
# Software engineering ./History_of_software_engineering
# ./History_of_general-purpose_CPUs General-purpose CPUs ['mw:WikiLink']
# General-purpose CPUs ./History_of_general-purpose_CPUs
# ./History_of_the_graphical_user_interface Graphical user interface ['mw:WikiLink']
# Graphical user interface ./History_of_the_graphical_user_interface
# ./History_of_the_Internet Internet ['mw:WikiLink']
# Internet ./History_of_the_Internet
# ./History_of_laptops Laptops ['mw:WikiLink']
# Laptops ./History_of_laptops
# ./History_of_personal_computers Personal computers ['mw:WikiLink']
# Personal computers ./History_of_personal_computers
# ./History_of_video_games Video games ['mw:WikiLink']
# Video games ./History_of_video_games
# ./History_of_the_World_Wide_Web World Wide Web ['mw:WikiLink']
# World Wide Web ./History_of_the_World_Wide_Web
# ./History_of_cloud_computing Cloud ['mw:WikiLink']
# Cloud ./History_of_cloud_computing
# ./Timeline_of_quantum_computing_and_communication Quantum ['mw:WikiLink']
# Quantum ./Timeline_of_quantum_computing_and_communication
# ./History_of_computer_hardware_in_Bulgaria Bulgaria ['mw:WikiLink']
# Bulgaria ./History_of_computer_hardware_in_Bulgaria
# ./History_of_computer_hardware_in_Eastern_Bloc_countries Eastern Bloc ['mw:WikiLink']
# Eastern Bloc ./History_of_computer_hardware_in_Eastern_Bloc_countries
# ./History_of_computing_in_Poland Poland ['mw:WikiLink']
# Poland ./History_of_computing_in_Poland
# ./History_of_computing_in_Romania Romania ['mw:WikiLink']
# Romania ./History_of_computing_in_Romania
# ./History_of_computing_in_South_America South America ['mw:WikiLink']
# South America ./History_of_computing_in_South_America
# ./History_of_computing_in_the_Soviet_Union Soviet Union ['mw:WikiLink']
# Soviet Union ./History_of_computing_in_the_Soviet_Union
# ./History_of_computer_hardware_in_Yugoslavia Yugoslavia ['mw:WikiLink']
# Yugoslavia ./History_of_computer_hardware_in_Yugoslavia
# ./Timeline_of_computing Timeline of computing ['mw:WikiLink']
# Timeline of computing ./Timeline_of_computing
# ./Timeline_of_computing_hardware_before_1950 before 1950 ['mw:WikiLink']
# before 1950 ./Timeline_of_computing_hardware_before_1950
# ./Timeline_of_computing_1950–1979 1950–1979 ['mw:WikiLink']
# 1950–1979 ./Timeline_of_computing_1950–1979
# ./Timeline_of_computing_1980–1989 1980–1989 ['mw:WikiLink']
# 1980–1989 ./Timeline_of_computing_1980–1989
# ./Timeline_of_computing_1990–1999 1990–1999 ['mw:WikiLink']
# 1990–1999 ./Timeline_of_computing_1990–1999
# ./Timeline_of_computing_2000–2009 2000–2009 ['mw:WikiLink']
# 2000–2009 ./Timeline_of_computing_2000–2009
# ./Timeline_of_computing_2010–2019 2010–2019 ['mw:WikiLink']
# 2010–2019 ./Timeline_of_computing_2010–2019
# ./Timeline_of_computing_2020–present 2020–present ['mw:WikiLink']
# 2020–present ./Timeline_of_computing_2020–present
# ./Category:Computing_timelines more timelines ... ['mw:WikiLink']
# more timelines ... ./Category:Computing_timelines
# ./Glossary_of_computer_science Glossary of computer science ['mw:WikiLink']
# Glossary of computer science ./Glossary_of_computer_science
# ./Category:History_of_computing Category ['mw:WikiLink']
# Category ./Category:History_of_computing
# ./Template:History_of_computing v ['mw:WikiLink']
# v ./Template:History_of_computing
# ./Template_talk:History_of_computing t ['mw:WikiLink']
# t ./Template_talk:History_of_computing
# ./Special:EditPage/Template:History_of_computing e ['mw:WikiLink']
# e ./Special:EditPage/Template:History_of_computing
# ./File:Christoph_Bernhard_Francke_-_Bildnis_des_Philosophen_Leibniz_(ca._1695).jpg  []
# ./Gottfried_Wilhelm_Leibniz Gottfried Wilhelm Leibniz ['mw:WikiLink']
# Gottfried Wilhelm Leibniz ./Gottfried_Wilhelm_Leibniz
# ./Logic logic ['mw:WikiLink']
# logic ./Logic
# ./Binary_number binary number ['mw:WikiLink']
# binary number ./Binary_number
# ./Computer_science#cite_note-13 [13] []
# ./File:Babbage40.png  []
# ./Charles_Babbage Charles Babbage ['mw:WikiLink']
# Charles Babbage ./Charles_Babbage
# ./Computer_science#cite_note-14 [14] []
# ./File:Ada_lovelace.jpg  []
# ./Ada_Lovelace Ada Lovelace ['mw:WikiLink']
# Ada Lovelace ./Ada_Lovelace
# ./Algorithm algorithm ['mw:WikiLink']
# algorithm ./Algorithm
# ./Computer_science#cite_note-15 [15] []
# ./Digital_computer digital computer ['mw:WikiLink']
# digital computer ./Digital_computer
# ./Abacus abacus ['mw:WikiLink']
# abacus ./Abacus
# ./Algorithm Algorithms ['mw:WikiLink']
# Algorithms ./Algorithm
# ./Computer_science#cite_note-16 [16] []
# ./Wilhelm_Schickard Wilhelm Schickard ['mw:WikiLink']
# Wilhelm Schickard ./Wilhelm_Schickard
# ./Mechanical_calculator mechanical calculator ['mw:WikiLink']
# mechanical calculator ./Mechanical_calculator
# ./Computer_science#cite_note-17 [17] []
# ./Gottfried_Leibniz Gottfried Leibniz ['mw:WikiLink']
# Gottfried Leibniz ./Gottfried_Leibniz
# ./Stepped_Reckoner Stepped Reckoner ['mw:WikiLink']
# Stepped Reckoner ./Stepped_Reckoner
# ./Computer_science#cite_note-18 [18] []
# ./Computer_scientist computer scientist ['mw:WikiLink']
# computer scientist ./Computer_scientist
# ./Thomas_de_Colmar Thomas de Colmar ['mw:WikiLink']
# Thomas de Colmar ./Thomas_de_Colmar
# ./Computer_science#cite_note-19 [note 1] []
# ./Arithmometer arithmometer ['mw:WikiLink']
# arithmometer ./Arithmometer
# ./Charles_Babbage Charles Babbage ['mw:WikiLink']
# Charles Babbage ./Charles_Babbage
# ./Difference_Engine Difference Engine ['mw:WikiLink']
# Difference Engine ./Difference_Engine
# ./Analytical_Engine Analytical Engine ['mw:WikiLink']
# Analytical Engine ./Analytical_Engine
# ./Computer_science#cite_note-20 [19] []
# https://en.wiktionary.org/wiki/Special:Search/salient salient ['mw:WikiLink/Interwiki']
# ./Computer_science#cite_note-Hyman1982-21 [20] []
# ./Jacquard_loom Jacquard loom ['mw:WikiLink']
# Jacquard loom ./Jacquard_loom
# ./Computer_science#cite_note-Hyman1982-21 [20] []
# ./Computer_science#cite_note-22 [note 2] []
# ./Ada_Lovelace Ada Lovelace ['mw:WikiLink']
# Ada Lovelace ./Ada_Lovelace
# ./Bernoulli_number Bernoulli numbers ['mw:WikiLink']
# Bernoulli numbers ./Bernoulli_number
# ./Computer_science#cite_note-23 [21] []
# ./Herman_Hollerith Herman Hollerith ['mw:WikiLink']
# Herman Hollerith ./Herman_Hollerith
# ./Tabulating_machine tabulator ['mw:WikiLink']
# tabulator ./Tabulating_machine
# ./Punched_card punched cards ['mw:WikiLink']
# punched cards ./Punched_card
# ./IBM IBM ['mw:WikiLink']
# IBM ./IBM
# ./Percy_Ludgate Percy Ludgate ['mw:WikiLink']
# Percy Ludgate ./Percy_Ludgate
# ./Computer_science#cite_note-24 [22] []
# ./Leonardo_Torres_Quevedo Leonardo Torres Quevedo ['mw:WikiLink']
# Leonardo Torres Quevedo ./Leonardo_Torres_Quevedo
# ./Computer_science#cite_note-LTQ1914es-25 [23] []
# ./Floating-point_arithmetic floating-point arithmetic ['mw:WikiLink']
# floating-point arithmetic ./Floating-point_arithmetic
# ./Computer_science#cite_note-26 [24] []
# ./Computer_science#cite_note-27 [25] []
# ./Leonardo_Torres_y_Quevedo#Analytical_machines Electromechanical Arithmometer ['mw:WikiLink']
# Electromechanical Arithmometer ./Leonardo_Torres_y_Quevedo#Analytical_machines
# ./Computer_science#cite_note-28 [26] []
# ./Computer_science#cite_note-FOOTNOTERandell19826,_11–13-29 [27] []
# ./Howard_Aiken Howard Aiken ['mw:WikiLink']
# Howard Aiken ./Howard_Aiken
# ./Computer_science#cite_note-30 [28] []
# ./Harvard_Mark_I ASCC/Harvard Mark I ['mw:WikiLink']
# ASCC/Harvard Mark I ./Harvard_Mark_I
# ./Computer_science#cite_note-31 [29] []
# ./Computing computing ['mw:WikiLink']
# computing ./Computing
# ./Atanasoff–Berry_computer Atanasoff–Berry computer ['mw:WikiLink']
# Atanasoff–Berry computer ./Atanasoff–Berry_computer
# ./ENIAC ENIAC ['mw:WikiLink']
# ENIAC ./ENIAC
# ./Computer_science#cite_note-32 [30] []
# ./Computation computation ['mw:WikiLink']
# computation ./Computation
# ./Watson_Scientific_Computing_Laboratory Watson Scientific Computing Laboratory ['mw:WikiLink']
# Watson Scientific Computing Laboratory ./Watson_Scientific_Computing_Laboratory
# ./Columbia_University Columbia University ['mw:WikiLink']
# Columbia University ./Columbia_University
# ./New_York_City New York City ['mw:WikiLink']
# New York City ./New_York_City
# ./Computer_science#cite_note-33 [31] []
# ./Computer_science#cite_note-34 [32] []
# ./Computer_science#cite_note-Denning-35 [33] []
# ./Computer_science#cite_note-36 [34] []
# ./Cambridge_Diploma_in_Computer_Science Cambridge Diploma in Computer Science ['mw:WikiLink']
# Cambridge Diploma in Computer Science ./Cambridge_Diploma_in_Computer_Science
# ./University_of_Cambridge_Computer_Laboratory University of Cambridge Computer Laboratory ['mw:WikiLink']
# University of Cambridge Computer Laboratory ./University_of_Cambridge_Computer_Laboratory
# ./Purdue_University Purdue University ['mw:WikiLink']
# Purdue University ./Purdue_University
# ./Computer_science#cite_note-37 [35] []
# ./History_of_computing History of computing ['mw:WikiLink']
# History of computing ./History_of_computing
# ./History_of_informatics History of informatics ['mw:WikiLink']
# History of informatics ./History_of_informatics
# ./Informatics#Etymology Informatics § Etymology ['mw:WikiLink']
# Informatics § Etymology ./Informatics#Etymology
# ./Computer_science#cite_note-Tedre2014-38 [36] []
# ./Communications_of_the_ACM Communications of the ACM ['mw:WikiLink']
# Communications of the ACM ./Communications_of_the_ACM
# ./Computer_science#cite_note-Fine_1959-39 [37] []
# ./Harvard_Business_School Harvard Business School ['mw:WikiLink']
# Harvard Business School ./Harvard_Business_School
# ./Computer_science#cite_note-40 [38] []
# ./Management_science management science ['mw:WikiLink']
# management science ./Management_science
# ./Computer_science#cite_note-Fine_1959-39 [37] []
# ./Numerical_analyst numerical analyst ['mw:WikiLink']
# numerical analyst ./Numerical_analyst
# ./George_Forsythe George Forsythe ['mw:WikiLink']
# George Forsythe ./George_Forsythe
# ./Computer_science#cite_note-41 [39] []
# ./Computer_science#cite_note-42 [40] []
# ./Peter_Naur Peter Naur ['mw:WikiLink']
# Peter Naur ./Peter_Naur
# ./Computer_science#cite_note-43 [41] []
# ./Data_science data science ['mw:WikiLink']
# data science ./Data_science
# ./Multi-disciplinary multi-disciplinary ['mw:WikiLink']
# multi-disciplinary ./Multi-disciplinary
# ./Epistemologist epistemologist ['mw:WikiLink']
# epistemologist ./Epistemologist
# ./Computer_science#cite_note-44 [42] []
# ./Computer_science#cite_note-45 [43] []
# ./Computer_science#cite_note-46 [44] []
# ./Slavic_languages Slavic languages ['mw:WikiLink']
# Slavic languages ./Slavic_languages
# ./Hungarian_language Hungarian ['mw:WikiLink']
# Hungarian ./Hungarian_language
# ./Greek_language Greek ['mw:WikiLink']
# Greek ./Greek_language
# ./School_of_Informatics,_University_of_Edinburgh School of Informatics, University of Edinburgh ['mw:WikiLink']
# School of Informatics, University of Edinburgh ./School_of_Informatics,_University_of_Edinburgh
# ./Computer_science#cite_note-47 [45] []
# ./Informatics informatics ['mw:WikiLink']
# informatics ./Informatics
# ./Computer_science#cite_note-48 [46] []
# ./Edsger_Dijkstra Edsger Dijkstra ['mw:WikiLink']
# Edsger Dijkstra ./Edsger_Dijkstra
# ./Computer_science#cite_note-49 [note 3] []
# ./Computer_engineering computer engineering ['mw:WikiLink']
# computer engineering ./Computer_engineering
# ./Computer_system computer systems ['mw:WikiLink']
# computer systems ./Computer_system
# ./Information_system information systems ['mw:WikiLink']
# information systems ./Information_system
# ./Cognitive_science cognitive science ['mw:WikiLink']
# cognitive science ./Cognitive_science
# ./Computational_linguistics linguistics ['mw:WikiLink']
# linguistics ./Computational_linguistics
# ./Mathematics mathematics ['mw:WikiLink']
# mathematics ./Mathematics
# ./Physics physics ['mw:WikiLink']
# physics ./Physics
# ./Biology biology ['mw:WikiLink']
# biology ./Biology
# ./Earth_science Earth science ['mw:WikiLink']
# Earth science ./Earth_science
# ./Computational_statistics statistics ['mw:WikiLink']
# statistics ./Computational_statistics
# ./Philosophy philosophy ['mw:WikiLink']
# philosophy ./Philosophy
# ./Logic logic ['mw:WikiLink']
# logic ./Logic
# ./Computer_science#cite_note-Denning-35 [33] []
# ./Kurt_Gödel Kurt Gödel ['mw:WikiLink']
# Kurt Gödel ./Kurt_Gödel
# ./Alan_Turing Alan Turing ['mw:WikiLink']
# Alan Turing ./Alan_Turing
# ./John_von_Neumann John von Neumann ['mw:WikiLink']
# John von Neumann ./John_von_Neumann
# ./Rózsa_Péter Rózsa Péter ['mw:WikiLink']
# Rózsa Péter ./Rózsa_Péter
# ./Alonzo_Church Alonzo Church ['mw:WikiLink']
# Alonzo Church ./Alonzo_Church
# ./Mathematical_logic mathematical logic ['mw:WikiLink']
# mathematical logic ./Mathematical_logic
# ./Category_theory category theory ['mw:WikiLink']
# category theory ./Category_theory
# ./Domain_theory domain theory ['mw:WikiLink']
# domain theory ./Domain_theory
# ./Algebra algebra ['mw:WikiLink']
# algebra ./Algebra
# ./Computer_science#cite_note-Tedre2014-38 [36] []
# ./Software_engineering#Suitability disputes ['mw:WikiLink']
# disputes ./Software_engineering#Suitability
# ./Computer_science#cite_note-50 [47] []
# ./David_Parnas David Parnas ['mw:WikiLink']
# David Parnas ./David_Parnas
# ./Computer_science#cite_note-51 [48] []
# ./Computational_science computational science ['mw:WikiLink']
# computational science ./Computational_science
# ./Philosophy_of_computer_science Philosophy of computer science ['mw:WikiLink']
# Philosophy of computer science ./Philosophy_of_computer_science
# ./Computer_science#cite_note-Luk20-52 [49] []
# ./Computer_science#cite_note-Knuth74-53 [50] []
# ./Computer_science#cite_note-plato-54 [51] []
# ./Allen_Newell Allen Newell ['mw:WikiLink']
# Allen Newell ./Allen_Newell
# ./Herbert_A._Simon Herbert A. Simon ['mw:WikiLink']
# Herbert A. Simon ./Herbert_A._Simon
# ./Computer_science#cite_note-plato-54 [51] []
# ./Correctness_(computer_science) correctness of programs ['mw:WikiLink']
# correctness of programs ./Correctness_(computer_science)
# ./Computer_science#cite_note-plato-54 [51] []
# ./Civil_engineering civil engineering ['mw:WikiLink']
# civil engineering ./Civil_engineering
# ./Aerospace_engineering aerospace engineering ['mw:WikiLink']
# aerospace engineering ./Aerospace_engineering
# ./Computer_science#cite_note-plato-54 [51] []
# ./Computer_science#cite_note-plato-54 [51] []
# ./Deductive_reasoning deductively reasoned ['mw:WikiLink']
# deductively reasoned ./Deductive_reasoning
# ./Formal_methods formal methods ['mw:WikiLink']
# formal methods ./Formal_methods
# ./Computer_science#cite_note-plato-54 [51] []
# ./Edsger_W._Dijkstra Edsger W. Dijkstra ['mw:WikiLink']
# Edsger W. Dijkstra ./Edsger_W._Dijkstra
# ./Tony_Hoare Tony Hoare ['mw:WikiLink']
# Tony Hoare ./Tony_Hoare
# ./Axiomatic_system axiomatic systems ['mw:WikiLink']
# axiomatic systems ./Axiomatic_system
# ./Computer_science#cite_note-plato-54 [51] []
# ./Peter_Wegner Peter Wegner ['mw:WikiLink']
# Peter Wegner ./Peter_Wegner
# ./Computer_science#cite_note-55 [52] []
# ./Peter_J._Denning Peter Denning ['mw:WikiLink']
# Peter Denning ./Peter_J._Denning
# ./Computer_science#cite_note-Denning-35 [33] []
# ./Natural_science natural sciences ['mw:WikiLink']
# natural sciences ./Natural_science
# ./Computer_science#cite_note-denning07-56 [53] []
# ./Artificial_intelligence artificial intelligence ['mw:WikiLink']
# artificial intelligence ./Artificial_intelligence
# ./Computer_science#cite_note-57 [54] []
# ./Computer_science#cite_note-58 [55] []
# ./Wikipedia:WikiProject_Lists#Dynamic_lists dynamic list ['mw:WikiLink']
# dynamic list ./Wikipedia:WikiProject_Lists#Dynamic_lists
# ./Special:EditPage/Computer_science adding missing items ['mw:WikiLink']
# adding missing items ./Special:EditPage/Computer_science
# ./Wikipedia:Reliable_sources reliable sources ['mw:WikiLink']
# reliable sources ./Wikipedia:Reliable_sources
# ./Outline_of_computer_science Outline of computer science ['mw:WikiLink']
# Outline of computer science ./Outline_of_computer_science
# ./Computer_science#cite_note-CSAB1997-59 [56] []
# ./Computer_science#cite_note-60 [57] []
# ./CSAB_(professional_organization) CSAB ['mw:WikiLink']
# CSAB ./CSAB_(professional_organization)
# ./Association_for_Computing_Machinery Association for Computing Machinery ['mw:WikiLink']
# Association for Computing Machinery ./Association_for_Computing_Machinery
# ./IEEE_Computer_Society IEEE Computer Society ['mw:WikiLink']
# IEEE Computer Society ./IEEE_Computer_Society
# ./Computer_science#cite_note-61 [58] []
# ./Symbolic_computation symbolic computation ['mw:WikiLink']
# symbolic computation ./Symbolic_computation
# ./Computer_science#cite_note-CSAB1997-59 [56] []
# ./Theoretical_computer_science Theoretical computer science ['mw:WikiLink']
# Theoretical computer science ./Theoretical_computer_science
# ./Theory_of_computation Theory of computation ['mw:WikiLink']
# Theory of computation ./Theory_of_computation
# ./Computer_science#cite_note-DenningAutomated-3 [3] []
# ./Computability_theory computability theory ['mw:WikiLink']
# computability theory ./Computability_theory
# ./Models_of_computation models of computation ['mw:WikiLink']
# models of computation ./Models_of_computation
# ./Computational_complexity_theory computational complexity theory ['mw:WikiLink']
# computational complexity theory ./Computational_complexity_theory
# ./P_=_NP%3F P = NP? ['mw:WikiLink']
# P = NP? ./P_=_NP%3F
# ./Millennium_Prize_Problems Millennium Prize Problems ['mw:WikiLink']
# Millennium Prize Problems ./Millennium_Prize_Problems
# ./Computer_science#cite_note-62 [59] []
# ./File:DFAexample.svg  []
# ./File:Syntax_tree.svg  []
# ./File:Complexity_classes.svg  []
# ./Automata_theory Automata theory ['mw:WikiLink']
# Automata theory ./Automata_theory
# ./Formal_language Formal languages ['mw:WikiLink']
# Formal languages ./Formal_language
# ./Computability_theory Computability theory ['mw:WikiLink']
# Computability theory ./Computability_theory
# ./Computational_complexity_theory Computational complexity theory ['mw:WikiLink']
# Computational complexity theory ./Computational_complexity_theory
# ./File:Interaction_Net_as_Configuration.png  []
# ./File:Blochsphere.svg  []
# ./File:XNOR_ANSI_Labelled.svg  []
# ./File:Kellerautomat.svg  []
# ./Models_of_computation Models of computation ['mw:WikiLink']
# Models of computation ./Models_of_computation
# ./Quantum_computer Quantum computing theory ['mw:WikiLink']
# Quantum computing theory ./Quantum_computer
# ./Circuit_(computer_science) Logic circuit theory ['mw:WikiLink']
# Logic circuit theory ./Circuit_(computer_science)
# ./Cellular_automata Cellular automata ['mw:WikiLink']
# Cellular automata ./Cellular_automata
# ./Information_theory Information theory ['mw:WikiLink']
# Information theory ./Information_theory
# ./Coding_theory Coding theory ['mw:WikiLink']
# Coding theory ./Coding_theory
# ./Probability probability ['mw:WikiLink']
# probability ./Probability
# ./Statistics statistics ['mw:WikiLink']
# statistics ./Statistics
# ./Claude_Shannon Claude Shannon ['mw:WikiLink']
# Claude Shannon ./Claude_Shannon
# ./Signal_processing signal processing ['mw:WikiLink']
# signal processing ./Signal_processing
# ./Computer_science#cite_note-63 [60] []
# ./Code codes ['mw:WikiLink']
# codes ./Code
# ./Data_compression data compression ['mw:WikiLink']
# data compression ./Data_compression
# ./Cryptography cryptography ['mw:WikiLink']
# cryptography ./Cryptography
# ./Error_detection_and_correction error detection and correction ['mw:WikiLink']
# error detection and correction ./Error_detection_and_correction
# ./Network_coding network coding ['mw:WikiLink']
# network coding ./Network_coding
# ./Data_transmission data transmission ['mw:WikiLink']
# data transmission ./Data_transmission
# ./Computer_science#cite_note-64 [61] []
# ./File:Hamming.jpg  []
# ./File:Binary_symmetric_channel.svg  []
# ./File:Digitalteilchen.svg  []
# ./File:H0_h1_fehler.jpg  []
# ./File:Mandelpart2_red.png  []
# ./Coding_theory Coding theory ['mw:WikiLink']
# Coding theory ./Coding_theory
# ./Channel_capacity Channel capacity ['mw:WikiLink']
# Channel capacity ./Channel_capacity
# ./Algorithmic_information_theory Algorithmic information theory ['mw:WikiLink']
# Algorithmic information theory ./Algorithmic_information_theory
# ./Signal_detection_theory Signal detection theory ['mw:WikiLink']
# Signal detection theory ./Signal_detection_theory
# ./Kolmogorov_complexity Kolmogorov complexity ['mw:WikiLink']
# Kolmogorov complexity ./Kolmogorov_complexity
# ./Data_structure Data structure ['mw:WikiLink']
# Data structure ./Data_structure
# ./Algorithm Algorithm ['mw:WikiLink']
# Algorithm ./Algorithm
# ./File:Sorting_quicksort_anim.gif  []
# ./File:Tree_(computer_science).svg  []
# ./File:TSP_Deutschland_3.png  []
# ./File:SimplexRangeSearching.svg  []
# ./File:Contraction_vertices.jpg  []
# ./Analysis_of_algorithms Analysis of algorithms ['mw:WikiLink']
# Analysis of algorithms ./Analysis_of_algorithms
# ./Algorithmics Algorithm design ['mw:WikiLink']
# Algorithm design ./Algorithmics
# ./Data_structures Data structures ['mw:WikiLink']
# Data structures ./Data_structures
# ./Combinatorial_optimization Combinatorial optimization ['mw:WikiLink']
# Combinatorial optimization ./Combinatorial_optimization
# ./Computational_geometry Computational geometry ['mw:WikiLink']
# Computational geometry ./Computational_geometry
# ./Randomized_algorithms Randomized algorithms ['mw:WikiLink']
# Randomized algorithms ./Randomized_algorithms
# ./Programming_language_theory Programming language theory ['mw:WikiLink']
# Programming language theory ./Programming_language_theory
# ./Formal_methods Formal methods ['mw:WikiLink']
# Formal methods ./Formal_methods
# ./Programming_language programming languages ['mw:WikiLink']
# programming languages ./Programming_language
# ./Programming_language#Elements features ['mw:WikiLink']
# features ./Programming_language#Elements
# ./Linguistics linguistics ['mw:WikiLink']
# linguistics ./Linguistics
# ./Formal_specification specification ['mw:WikiLink']
# specification ./Formal_specification
# ./Formal_verification verification ['mw:WikiLink']
# verification ./Formal_verification
# ./Computer_hardware hardware ['mw:WikiLink']
# hardware ./Computer_hardware
# ./Computer_science#cite_note-65 [62] []
# ./Life-critical_system life-critical systems ['mw:WikiLink']
# life-critical systems ./Life-critical_system
# ./Computer_security security ['mw:WikiLink']
# security ./Computer_security
# ./Theoretical_computer_science theoretical computer science ['mw:WikiLink']
# theoretical computer science ./Theoretical_computer_science
# ./Logic_in_computer_science logic ['mw:WikiLink']
# logic ./Logic_in_computer_science
# ./Formal_language formal languages ['mw:WikiLink']
# formal languages ./Formal_language
# ./Automata_theory automata theory ['mw:WikiLink']
# automata theory ./Automata_theory
# ./Program_semantics program semantics ['mw:WikiLink']
# program semantics ./Program_semantics
# ./Type_systems type systems ['mw:WikiLink']
# type systems ./Type_systems
# ./Algebraic_data_types algebraic data types ['mw:WikiLink']
# algebraic data types ./Algebraic_data_types
# ./File:IF-THEN-ELSE-END_flowchart.svg  []
# ./File:Compiler.svg  []
# ./File:Python_add5_syntax.svg  []
# ./File:Prop-tableau-1.svg  []
# ./File:Coq_plus_comm_screenshot.jpg  []
# ./Semantics_(computer_science) Formal semantics ['mw:WikiLink']
# Formal semantics ./Semantics_(computer_science)
# ./Type_theory Type theory ['mw:WikiLink']
# Type theory ./Type_theory
# ./Compiler_design Compiler design ['mw:WikiLink']
# Compiler design ./Compiler_design
# ./Programming_language Programming languages ['mw:WikiLink']
# Programming languages ./Programming_language
# ./Formal_verification Formal verification ['mw:WikiLink']
# Formal verification ./Formal_verification
# ./Automated_theorem_proving Automated theorem proving ['mw:WikiLink']
# Automated theorem proving ./Automated_theorem_proving
# ./Computer_graphics_(computer_science) Computer graphics (computer science) ['mw:WikiLink']
# Computer graphics (computer science) ./Computer_graphics_(computer_science)
# ./Computer_vision computer vision ['mw:WikiLink']
# computer vision ./Computer_vision
# ./Image_processing image processing ['mw:WikiLink']
# image processing ./Image_processing
# ./Computational_geometry computational geometry ['mw:WikiLink']
# computational geometry ./Computational_geometry
# ./Video_game video games ['mw:WikiLink']
# video games ./Video_game
# ./File:Simx2=transl_OK.svg  []
# ./File:FWDvsINV_Kinematics_HighResTransp.png  []
# ./File:5-cell.gif  []
# ./File:Hud_on_the_cat.jpg  []
# ./File:Visible_light_eye-tracking_algorithm.jpg  []
# ./File:Csg_tree.png  []
# ./2D_computer_graphics 2D computer graphics ['mw:WikiLink']
# 2D computer graphics ./2D_computer_graphics
# ./Computer_animation Computer animation ['mw:WikiLink']
# Computer animation ./Computer_animation
# ./Rendering_(computer_graphics) Rendering ['mw:WikiLink']
# Rendering ./Rendering_(computer_graphics)
# ./Mixed_reality Mixed reality ['mw:WikiLink']
# Mixed reality ./Mixed_reality
# ./Virtual_reality Virtual reality ['mw:WikiLink']
# Virtual reality ./Virtual_reality
# ./Solid_modeling Solid modeling ['mw:WikiLink']
# Solid modeling ./Solid_modeling
# ./Data_processing Data processing ['mw:WikiLink']
# Data processing ./Data_processing
# ./Information Information ['mw:WikiLink']
# Information ./Information
# ./Bit Bits ['mw:WikiLink']
# Bits ./Bit
# ./Signal signals ['mw:WikiLink']
# signals ./Signal
# ./Data_processing processing ['mw:WikiLink']
# processing ./Data_processing
# ./Information_theory information theory ['mw:WikiLink']
# information theory ./Information_theory
# ./Telecommunications telecommunications ['mw:WikiLink']
# telecommunications ./Telecommunications
# ./Information_engineering information engineering ['mw:WikiLink']
# information engineering ./Information_engineering
# ./Medical_image_computing medical image computing ['mw:WikiLink']
# medical image computing ./Medical_image_computing
# ./Speech_synthesis speech synthesis ['mw:WikiLink']
# speech synthesis ./Speech_synthesis
# ./Fast_Fourier_transform fast Fourier transform ['mw:WikiLink']
# fast Fourier transform ./Fast_Fourier_transform
# ./List_of_unsolved_problems_in_computer_science unsolved problems in theoretical computer science ['mw:WikiLink']
# unsolved problems in theoretical computer science ./List_of_unsolved_problems_in_computer_science
# ./File:DIT-FFT-butterfly.png  []
# ./File:Bayer_pattern_on_sensor.svg  []
# ./File:Opus_quality_comparison_colorblind_compatible.svg  []
# ./File:Quality_comparison_jpg_vs_saveforweb.jpg  []
# ./File:MeningiomaMRISegmentation.png  []
# ./File:Ætoms_-_Translation.svg  []
# ./Fast_Fourier_transform FFT algorithms ['mw:WikiLink']
# FFT algorithms ./Fast_Fourier_transform
# ./Image_processing Image processing ['mw:WikiLink']
# Image processing ./Image_processing
# ./Speech_recognition Speech recognition ['mw:WikiLink']
# Speech recognition ./Speech_recognition
# ./Data_compression Data compression ['mw:WikiLink']
# Data compression ./Data_compression
# ./Medical_image_computing Medical image computing ['mw:WikiLink']
# Medical image computing ./Medical_image_computing
# ./Speech_synthesis Speech synthesis ['mw:WikiLink']
# Speech synthesis ./Speech_synthesis
# ./Computational_science Computational science ['mw:WikiLink']
# Computational science ./Computational_science
# ./Computational_finance Computational finance ['mw:WikiLink']
# Computational finance ./Computational_finance
# ./Computational_engineering Computational engineering ['mw:WikiLink']
# Computational engineering ./Computational_engineering
# ./List_of_computer-aided_engineering_software List of computer-aided engineering software ['mw:WikiLink']
# List of computer-aided engineering software ./List_of_computer-aided_engineering_software
# ./Scientific_computing Scientific computing ['mw:WikiLink']
# Scientific computing ./Scientific_computing
# ./Scientific_modelling mathematical models ['mw:WikiLink']
# mathematical models ./Scientific_modelling
# ./Numerical_analysis quantitative analysis ['mw:WikiLink']
# quantitative analysis ./Numerical_analysis
# ./Scientific scientific ['mw:WikiLink']
# scientific ./Scientific
# ./Simulation simulation ['mw:WikiLink']
# simulation ./Simulation
# ./Fluid_dynamics fluid dynamics ['mw:WikiLink']
# fluid dynamics ./Fluid_dynamics
# ./Computer_science#cite_note-66 [63] []
# ./Integrated_circuit integrated circuits ['mw:WikiLink']
# integrated circuits ./Integrated_circuit
# ./Computer_science#cite_note-67 [64] []
# ./File:Lorenz_attractor_yb.svg  []
# ./File:Quark_wiki.jpg  []
# ./File:Naphthalene-3D-balls.png  []
# ./File:1u04-argonaute.png  []
# ./File:GalvesLocherbach_-_Low_resolution.gif  []
# ./File:Plutchik-wheel.svg  []
# ./File:X-ray_of_hand,_where_bone_age_is_automatically_found_by_BoneXpert_software.jpg  []
# ./File:Elmer-pump-heatequation.png  []
# ./File:Bachlut1.png  []
# ./Numerical_analysis Numerical analysis ['mw:WikiLink']
# Numerical analysis ./Numerical_analysis
# ./Computational_physics Computational physics ['mw:WikiLink']
# Computational physics ./Computational_physics
# ./Computational_chemistry Computational chemistry ['mw:WikiLink']
# Computational chemistry ./Computational_chemistry
# ./Bioinformatics Bioinformatics ['mw:WikiLink']
# Bioinformatics ./Bioinformatics
# ./Neuroinformatics Neuroinformatics ['mw:WikiLink']
# Neuroinformatics ./Neuroinformatics
# ./Psychoinformatics Psychoinformatics ['mw:WikiLink']
# Psychoinformatics ./Psychoinformatics
# ./Medical_informatics Medical informatics ['mw:WikiLink']
# Medical informatics ./Medical_informatics
# ./Computational_engineering Computational engineering ['mw:WikiLink']
# Computational engineering ./Computational_engineering
# ./Computational_musicology Computational musicology ['mw:WikiLink']
# Computational musicology ./Computational_musicology
# ./Human–computer_interaction Human–computer interaction ['mw:WikiLink']
# Human–computer interaction ./Human–computer_interaction
# ./Computer computer systems ['mw:WikiLink']
# computer systems ./Computer
# ./Human humans ['mw:WikiLink']
# humans ./Human
# ./Interface_(computing) computer interfaces ['mw:WikiLink']
# computer interfaces ./Interface_(computing)
# ./Human–computer_interaction#Current_research subfields ['mw:WikiLink']
# subfields ./Human–computer_interaction#Current_research
# ./Emotion emotions ['mw:WikiLink']
# emotions ./Emotion
# ./Social_behavior social behavior ['mw:WikiLink']
# social behavior ./Social_behavior
# ./Electroencephalography brain activity ['mw:WikiLink']
# brain activity ./Electroencephalography
# ./Computer computers ['mw:WikiLink']
# computers ./Computer
# ./File:Maker_Faire,_Berlin_(BL7C0099).jpg  []
# ./File:InterfaceNeuronaleDirecte-tag.svg  []
# ./File:Human-Centered_Design-Prozess_nach_HBS.png  []
# ./File:Physical_computing.svg  []
# ./File:WMID_social_media_network.png  []
# ./Affective_computing Affective computing ['mw:WikiLink']
# Affective computing ./Affective_computing
# ./Brain–computer_interface Brain–computer interface ['mw:WikiLink']
# Brain–computer interface ./Brain–computer_interface
# ./Human-centered_design Human-centered design ['mw:WikiLink']
# Human-centered design ./Human-centered_design
# ./Physical_computing Physical computing ['mw:WikiLink']
# Physical computing ./Physical_computing
# ./Social_computing Social computing ['mw:WikiLink']
# Social computing ./Social_computing
# ./Software_engineering Software engineering ['mw:WikiLink']
# Software engineering ./Software_engineering
# ./Computer_programming Computer programming ['mw:WikiLink']
# Computer programming ./Computer_programming
# ./Software_testing software testing ['mw:WikiLink']
# software testing ./Software_testing
# ./Systems_engineering systems engineering ['mw:WikiLink']
# systems engineering ./Systems_engineering
# ./Technical_debt technical debt ['mw:WikiLink']
# technical debt ./Technical_debt
# ./Software_development_process software development processes ['mw:WikiLink']
# software development processes ./Software_development_process
# ./Artificial_intelligence Artificial intelligence ['mw:WikiLink']
# Artificial intelligence ./Artificial_intelligence
# ./Bio-inspired_computing Bio-inspired computing ['mw:WikiLink']
# Bio-inspired computing ./Bio-inspired_computing
# ./Cybernetics cybernetics ['mw:WikiLink']
# cybernetics ./Cybernetics
# ./History_of_artificial_intelligence Dartmouth Conference ['mw:WikiLink']
# Dartmouth Conference ./History_of_artificial_intelligence
# ./Applied_mathematics applied mathematics ['mw:WikiLink']
# applied mathematics ./Applied_mathematics
# ./Semiotics semiotics ['mw:WikiLink']
# semiotics ./Semiotics
# ./Electrical_engineering electrical engineering ['mw:WikiLink']
# electrical engineering ./Electrical_engineering
# ./Philosophy_of_mind philosophy of mind ['mw:WikiLink']
# philosophy of mind ./Philosophy_of_mind
# ./Neurophysiology neurophysiology ['mw:WikiLink']
# neurophysiology ./Neurophysiology
# ./Social_intelligence social intelligence ['mw:WikiLink']
# social intelligence ./Social_intelligence
# ./Robotics robotic development ['mw:WikiLink']
# robotic development ./Robotics
# ./Software_development software development ['mw:WikiLink']
# software development ./Software_development
# ./Computing_Machinery_and_Intelligence Can computers think? ['mw:WikiLink']
# Can computers think? ./Computing_Machinery_and_Intelligence
# ./Turing_test Turing test ['mw:WikiLink']
# Turing test ./Turing_test
# ./File:Nicolas_P._Rougier's_rendering_of_the_human_brain.png  []
# ./File:Human_eye,_rendered_from_Eye.png  []
# ./File:Colored_neural_network.svg  []
# ./File:Markov_Decision_Process.svg  []
# ./Computational_learning_theory Computational learning theory ['mw:WikiLink']
# Computational learning theory ./Computational_learning_theory
# ./Computer_vision Computer vision ['mw:WikiLink']
# Computer vision ./Computer_vision
# ./Artificial_neural_network Neural networks ['mw:WikiLink']
# Neural networks ./Artificial_neural_network
# ./Planning_and_scheduling Planning and scheduling ['mw:WikiLink']
# Planning and scheduling ./Planning_and_scheduling
# ./File:English.png  []
# ./File:Knight's_tour.svg  []
# ./File:Ackley.gif  []
# ./File:AutonomicSystemModel.png  []
# ./Natural_language_processing Natural language processing ['mw:WikiLink']
# Natural language processing ./Natural_language_processing
# ./Algorithmic_game_theory Computational game theory ['mw:WikiLink']
# Computational game theory ./Algorithmic_game_theory
# ./Evolutionary_computation Evolutionary computation ['mw:WikiLink']
# Evolutionary computation ./Evolutionary_computation
# ./Autonomic_computing Autonomic computing ['mw:WikiLink']
# Autonomic computing ./Autonomic_computing
# ./File:Neuron.svg  []
# ./File:KnnClassification.svg  []
# ./File:ROS_C_logo.jpg  []
# ./File:Rule_alignment.gif  []
# ./Knowledge_representation_and_reasoning Representation and reasoning ['mw:WikiLink']
# Representation and reasoning ./Knowledge_representation_and_reasoning
# ./Pattern_recognition Pattern recognition ['mw:WikiLink']
# Pattern recognition ./Pattern_recognition
# ./Robotics Robotics ['mw:WikiLink']
# Robotics ./Robotics
# ./Swarm_intelligence Swarm intelligence ['mw:WikiLink']
# Swarm intelligence ./Swarm_intelligence
# ./Computer_architecture Computer architecture ['mw:WikiLink']
# Computer architecture ./Computer_architecture
# ./Microarchitecture Microarchitecture ['mw:WikiLink']
# Microarchitecture ./Microarchitecture
# ./Computer_engineering Computer engineering ['mw:WikiLink']
# Computer engineering ./Computer_engineering
# ./Computer_science#cite_note-68 [65] []
# ./Computational_logic computational logic ['mw:WikiLink']
# computational logic ./Computational_logic
# ./Processor_(computing) processor ['mw:WikiLink']
# processor ./Processor_(computing)
# ./Microcontroller microcontrollers ['mw:WikiLink']
# microcontrollers ./Microcontroller
# ./Personal_computer personal computers ['mw:WikiLink']
# personal computers ./Personal_computer
# ./Supercomputer supercomputers ['mw:WikiLink']
# supercomputers ./Supercomputer
# ./Embedded_system embedded systems ['mw:WikiLink']
# embedded systems ./Embedded_system
# ./Frederick_P._Brooks_Jr. Frederick P. Brooks Jr. ['mw:WikiLink']
# Frederick P. Brooks Jr. ./Frederick_P._Brooks_Jr.
# ./File:ABasicComputer.svg  []
# ./File:Intel_Core2_arch.svg  []
# ./File:SIMD.svg  []
# ./File:Z80_arch.svg  []
# ./Processing_unit Processing unit ['mw:WikiLink']
# Processing unit ./Processing_unit
# ./Microarchitecture Microarchitecture ['mw:WikiLink']
# Microarchitecture ./Microarchitecture
# ./Multiprocessing Multiprocessing ['mw:WikiLink']
# Multiprocessing ./Multiprocessing
# ./Processor_design Processor design ['mw:WikiLink']
# Processor design ./Processor_design
# ./File:Roomba_original.jpg  []
# ./File:Flowchart.png  []
# ./File:Kernel_Layout.svg  []
# ./File:Uarm_metal_wiki2.jpg  []
# ./Ubiquitous_computing Ubiquitous computing ['mw:WikiLink']
# Ubiquitous computing ./Ubiquitous_computing
# ./Systems_architecture Systems architecture ['mw:WikiLink']
# Systems architecture ./Systems_architecture
# ./Operating_system Operating systems ['mw:WikiLink']
# Operating systems ./Operating_system
# ./Input/output Input/output ['mw:WikiLink']
# Input/output ./Input/output
# ./File:Physical_computing.svg  []
# ./File:FIR_Filter_General.svg  []
# ./File:Dep-1.svg  []
# ./File:Linker.svg  []
# ./Embedded_system Embedded system ['mw:WikiLink']
# Embedded system ./Embedded_system
# ./Real-time_computing Real-time computing ['mw:WikiLink']
# Real-time computing ./Real-time_computing
# ./Dependability Dependability ['mw:WikiLink']
# Dependability ./Dependability
# ./Interpreter_(computing) Interpreter ['mw:WikiLink']
# Interpreter ./Interpreter_(computing)
# ./Concurrency_(computer_science) Concurrency (computer science) ['mw:WikiLink']
# Concurrency (computer science) ./Concurrency_(computer_science)
# ./Distributed_computing Distributed computing ['mw:WikiLink']
# Distributed computing ./Distributed_computing
# ./Computer_science#cite_note-69 [66] []
# ./Petri_net Petri nets ['mw:WikiLink']
# Petri nets ./Petri_net
# ./Process_calculi process calculi ['mw:WikiLink']
# process calculi ./Process_calculi
# ./Parallel_random_access_machine parallel random access machine ['mw:WikiLink']
# parallel random access machine ./Parallel_random_access_machine
# ./Computer_science#cite_note-70 [67] []
# ./Computer_science#cite_note-71 [68] []
# ./Computer_network Computer network ['mw:WikiLink']
# Computer network ./Computer_network
# ./Computer_security Computer security ['mw:WikiLink']
# Computer security ./Computer_security
# ./Cryptography Cryptography ['mw:WikiLink']
# Cryptography ./Cryptography
# ./Cryptography cryptography ['mw:WikiLink']
# cryptography ./Cryptography
# ./Computer_science#cite_note-72 [69] []
# ./Encryption encryption ['mw:WikiLink']
# encryption ./Encryption
# ./Digital_signature digital signatures ['mw:WikiLink']
# digital signatures ./Digital_signature
# ./Cryptographic_hash_function cryptographic hash functions ['mw:WikiLink']
# cryptographic hash functions ./Cryptographic_hash_function
# ./Key-agreement_protocol key-agreement protocols ['mw:WikiLink']
# key-agreement protocols ./Key-agreement_protocol
# ./Blockchain blockchain ['mw:WikiLink']
# blockchain ./Blockchain
# ./Zero-knowledge_proof zero-knowledge proofs ['mw:WikiLink']
# zero-knowledge proofs ./Zero-knowledge_proof
# ./Garbled_circuit garbled circuits ['mw:WikiLink']
# garbled circuits ./Garbled_circuit
# ./Database Database ['mw:WikiLink']
# Database ./Database
# ./Data_mining Data mining ['mw:WikiLink']
# Data mining ./Data_mining
# ./Database_model database models ['mw:WikiLink']
# database models ./Database_model
# ./Query_language query languages ['mw:WikiLink']
# query languages ./Query_language
# ./William_J._Rapaport Bill Rapaport ['mw:WikiLink']
# Bill Rapaport ./William_J._Rapaport
# ./Computer_science#cite_note-73 [70] []
# ./Gottfried_Wilhelm_Leibniz Gottfried Wilhelm Leibniz ['mw:WikiLink']
# Gottfried Wilhelm Leibniz ./Gottfried_Wilhelm_Leibniz
# ./George_Boole George Boole ['mw:WikiLink']
# George Boole ./George_Boole
# ./Alan_Turing Alan Turing ['mw:WikiLink']
# Alan Turing ./Alan_Turing
# ./Claude_Shannon Claude Shannon ['mw:WikiLink']
# Claude Shannon ./Claude_Shannon
# ./Samuel_Morse Samuel Morse ['mw:WikiLink']
# Samuel Morse ./Samuel_Morse
# ./Computer_science#cite_note-74 [note 4] []
# ./Digital_physics Digital physics ['mw:WikiLink']
# Digital physics ./Digital_physics
# ./Alan_Turing Alan Turing ['mw:WikiLink']
# Alan Turing ./Alan_Turing
# ./Computer_science#cite_note-75 [71] []
# ./Turing_machine Turing machine ['mw:WikiLink']
# Turing machine ./Turing_machine
# ./Corrado_Böhm Corrado Böhm ['mw:WikiLink']
# Corrado Böhm ./Corrado_Böhm
# ./Computer_science#cite_note-76 [72] []
# ./Goto goto ['mw:WikiLink']
# goto ./Goto
# ./Structured_programming structured programming ['mw:WikiLink']
# structured programming ./Structured_programming
# ./Structured_program_theorem Structured program theorem ['mw:WikiLink']
# Structured program theorem ./Structured_program_theorem
# ./Programming_paradigm Programming paradigm ['mw:WikiLink']
# Programming paradigm ./Programming_paradigm
# ./Functional_programming Functional programming ['mw:WikiLink']
# Functional programming ./Functional_programming
# ./Computer_science#cite_note-77 [73] []
# ./Imperative_programming Imperative programming ['mw:WikiLink']
# Imperative programming ./Imperative_programming
# ./Computer_science#cite_note-78 [74] []
# ./Object-oriented_programming Object-oriented programming ['mw:WikiLink']
# Object-oriented programming ./Object-oriented_programming
# ./Computer_science#cite_note-79 [75] []
# ./Service-oriented_programming Service-oriented programming ['mw:WikiLink']
# Service-oriented programming ./Service-oriented_programming
# ./Mission_critical mission critical ['mw:WikiLink']
# mission critical ./Mission_critical
# ./Computer_science#cite_note-80 [76] []
# ...
# Operations research ./Operations_research
# ./Educational_technology Educational technology ['mw:WikiLink']
# Educational technology ./Educational_technology
# ./Document_management_system Document management ['mw:WikiLink']
# Document management ./Document_management_system
# ./Category:Computer_science Category ['mw:WikiLink']
# Category ./Category:Computer_science
# ./Outline_of_computer_science Outline ['mw:WikiLink']
# Outline ./Outline_of_computer_science
# ./Template:Glossaries_of_computers Glossaries ['mw:WikiLink']
# Glossaries ./Template:Glossaries_of_computers
# ./Template:Glossaries_of_science_and_engineering v ['mw:WikiLink']
# v ./Template:Glossaries_of_science_and_engineering
# ./Template_talk:Glossaries_of_science_and_engineering t ['mw:WikiLink']
# t ./Template_talk:Glossaries_of_science_and_engineering
# ./Special:EditPage/Template:Glossaries_of_science_and_engineering e ['mw:WikiLink']
# e ./Special:EditPage/Template:Glossaries_of_science_and_engineering
# ./Science science ['mw:WikiLink']
# science ./Science
# ./Engineering engineering ['mw:WikiLink']
# engineering ./Engineering
# ./Glossary_of_aerospace_engineering Aerospace engineering ['mw:WikiLink']
# Aerospace engineering ./Glossary_of_aerospace_engineering
# ./Glossary_of_agriculture Agriculture ['mw:WikiLink']
# Agriculture ./Glossary_of_agriculture
# ./Glossary_of_archaeology Archaeology ['mw:WikiLink']
# Archaeology ./Glossary_of_archaeology
# ./Glossary_of_architecture Architecture ['mw:WikiLink']
# Architecture ./Glossary_of_architecture
# ./Glossary_of_artificial_intelligence Artificial intelligence ['mw:WikiLink']
# Artificial intelligence ./Glossary_of_artificial_intelligence
# ./Glossary_of_astronomy Astronomy ['mw:WikiLink']
# Astronomy ./Glossary_of_astronomy
# ./Glossary_of_biology Biology ['mw:WikiLink']
# Biology ./Glossary_of_biology
# ./Glossary_of_botanical_terms Botany ['mw:WikiLink']
# Botany ./Glossary_of_botanical_terms
# ./Glossary_of_calculus Calculus ['mw:WikiLink']
# Calculus ./Glossary_of_calculus
# ./Glossary_of_cell_biology Cell biology ['mw:WikiLink']
# Cell biology ./Glossary_of_cell_biology
# ./Glossary_of_chemistry_terms Chemistry ['mw:WikiLink']
# Chemistry ./Glossary_of_chemistry_terms
# ./Glossary_of_civil_engineering Civil engineering ['mw:WikiLink']
# Civil engineering ./Glossary_of_civil_engineering
# ./Glossary_of_clinical_research Clinical research ['mw:WikiLink']
# Clinical research ./Glossary_of_clinical_research
# ./Glossary_of_computer_hardware_terms Computer hardware ['mw:WikiLink']
# Computer hardware ./Glossary_of_computer_hardware_terms
# ./Glossary_of_computer_science Computer science ['mw:WikiLink']
# Computer science ./Glossary_of_computer_science
# ./Glossary_of_developmental_biology Developmental and reproductive biology ['mw:WikiLink']
# Developmental and reproductive biology ./Glossary_of_developmental_biology
# ./Glossary_of_ecology Ecology ['mw:WikiLink']
# Ecology ./Glossary_of_ecology
# ./Glossary_of_economics Economics ['mw:WikiLink']
# Economics ./Glossary_of_economics
# ./Glossary_of_electrical_and_electronics_engineering Electrical and electronics engineering ['mw:WikiLink']
# Electrical and electronics engineering ./Glossary_of_electrical_and_electronics_engineering
# ./Glossary_of_engineering:_A–L A–L ['mw:WikiLink']
# A–L ./Glossary_of_engineering:_A–L
# ./Glossary_of_engineering:_M–Z M–Z ['mw:WikiLink']
# M–Z ./Glossary_of_engineering:_M–Z
# ./Glossary_of_entomology_terms Entomology ['mw:WikiLink']
# Entomology ./Glossary_of_entomology_terms
# ./Glossary_of_environmental_science Environmental science ['mw:WikiLink']
# Environmental science ./Glossary_of_environmental_science
# ./Glossary_of_genetics_and_evolutionary_biology Genetics and evolutionary biology ['mw:WikiLink']
# Genetics and evolutionary biology ./Glossary_of_genetics_and_evolutionary_biology
# ./Glossary_of_cellular_and_molecular_biology_(0–L) 0–L ['mw:WikiLink']
# 0–L ./Glossary_of_cellular_and_molecular_biology_(0–L)
# ./Glossary_of_cellular_and_molecular_biology_(M–Z) M–Z ['mw:WikiLink']
# M–Z ./Glossary_of_cellular_and_molecular_biology_(M–Z)
# ./Glossary_of_geography_terms_(A–M) A–M ['mw:WikiLink']
# A–M ./Glossary_of_geography_terms_(A–M)
# ./Glossary_of_geography_terms_(N–Z) N–Z ['mw:WikiLink']
# N–Z ./Glossary_of_geography_terms_(N–Z)
# ./Glossary_of_Arabic_toponyms Arabic toponyms ['mw:WikiLink']
# Arabic toponyms ./Glossary_of_Arabic_toponyms
# ./Glossary_of_Hebrew_toponyms Hebrew toponyms ['mw:WikiLink']
# Hebrew toponyms ./Glossary_of_Hebrew_toponyms
# ./Oikonyms_in_Western_and_South_Asia Western and South Asia ['mw:WikiLink']
# Western and South Asia ./Oikonyms_in_Western_and_South_Asia
# ./Glossary_of_geology Geology ['mw:WikiLink']
# Geology ./Glossary_of_geology
# ./Glossary_of_ichthyology Ichthyology ['mw:WikiLink']
# Ichthyology ./Glossary_of_ichthyology
# ./Glossary_of_machine_vision Machine vision ['mw:WikiLink']
# Machine vision ./Glossary_of_machine_vision
# ./Glossary_of_areas_of_mathematics Mathematics ['mw:WikiLink']
# Mathematics ./Glossary_of_areas_of_mathematics
# ./Glossary_of_mechanical_engineering Mechanical engineering ['mw:WikiLink']
# Mechanical engineering ./Glossary_of_mechanical_engineering
# ./Glossary_of_medicine Medicine ['mw:WikiLink']
# Medicine ./Glossary_of_medicine
# ./Glossary_of_meteorology Meteorology ['mw:WikiLink']
# Meteorology ./Glossary_of_meteorology
# ./Glossary_of_mycology Mycology ['mw:WikiLink']
# Mycology ./Glossary_of_mycology
# ./Glossary_of_nanotechnology Nanotechnology ['mw:WikiLink']
# Nanotechnology ./Glossary_of_nanotechnology
# ./Glossary_of_bird_terms Ornithology ['mw:WikiLink']
# Ornithology ./Glossary_of_bird_terms
# ./Glossary_of_physics Physics ['mw:WikiLink']
# Physics ./Glossary_of_physics
# ./Glossary_of_probability_and_statistics Probability and statistics ['mw:WikiLink']
# Probability and statistics ./Glossary_of_probability_and_statistics
# ./Glossary_of_psychiatry Psychiatry ['mw:WikiLink']
# Psychiatry ./Glossary_of_psychiatry
# ./Glossary_of_quantum_computing Quantum computing ['mw:WikiLink']
# Quantum computing ./Glossary_of_quantum_computing
# ./Glossary_of_robotics Robotics ['mw:WikiLink']
# Robotics ./Glossary_of_robotics
# ./Glossary_of_scientific_naming Scientific naming ['mw:WikiLink']
# Scientific naming ./Glossary_of_scientific_naming
# ./Glossary_of_structural_engineering Structural engineering ['mw:WikiLink']
# Structural engineering ./Glossary_of_structural_engineering
# ./Glossary_of_virology Virology ['mw:WikiLink']
# Virology ./Glossary_of_virology
# ./Template:Software_engineering v ['mw:WikiLink']
# v ./Template:Software_engineering
# ./Template_talk:Software_engineering t ['mw:WikiLink']
# t ./Template_talk:Software_engineering
# ./Special:EditPage/Template:Software_engineering e ['mw:WikiLink']
# e ./Special:EditPage/Template:Software_engineering
# ./Software_engineering Software engineering ['mw:WikiLink']
# Software engineering ./Software_engineering
# ./Computer_programming Computer programming ['mw:WikiLink']
# Computer programming ./Computer_programming
# ./DevOps DevOps ['mw:WikiLink']
# DevOps ./DevOps
# ./Empirical_software_engineering Empirical software engineering ['mw:WikiLink']
# Empirical software engineering ./Empirical_software_engineering
# ./Experimental_software_engineering Experimental software engineering ['mw:WikiLink']
# Experimental software engineering ./Experimental_software_engineering
# ./Formal_methods Formal methods ['mw:WikiLink']
# Formal methods ./Formal_methods
# ./Requirements_engineering Requirements engineering ['mw:WikiLink']
# Requirements engineering ./Requirements_engineering
# ./Search-based_software_engineering Search-based software engineering ['mw:WikiLink']
# Search-based software engineering ./Search-based_software_engineering
# ./Site_reliability_engineering Site reliability engineering ['mw:WikiLink']
# Site reliability engineering ./Site_reliability_engineering
# ./Social_software_engineering Social software engineering ['mw:WikiLink']
# Social software engineering ./Social_software_engineering
# ./Software_deployment Software deployment ['mw:WikiLink']
# Software deployment ./Software_deployment
# ./Software_design Software design ['mw:WikiLink']
# Software design ./Software_design
# ./Software_maintenance Software maintenance ['mw:WikiLink']
# Software maintenance ./Software_maintenance
# ./Software_testing Software testing ['mw:WikiLink']
# Software testing ./Software_testing
# ./Systems_analysis Systems analysis ['mw:WikiLink']
# Systems analysis ./Systems_analysis
# ./Abstraction_(computer_science) Abstraction ['mw:WikiLink']
# Abstraction ./Abstraction_(computer_science)
# ./Component-based_software_engineering Component-based software engineering ['mw:WikiLink']
# Component-based software engineering ./Component-based_software_engineering
# ./Computer_compatibility Software compatibility ['mw:WikiLink']
# Software compatibility ./Computer_compatibility
# ./Backward_compatibility Backward compatibility ['mw:WikiLink']
# Backward compatibility ./Backward_compatibility
# ./Compatibility_layer Compatibility layer ['mw:WikiLink']
# Compatibility layer ./Compatibility_layer
# ./Compatibility_mode Compatibility mode ['mw:WikiLink']
# Compatibility mode ./Compatibility_mode
# ./Forward_compatibility Forward compatibility ['mw:WikiLink']
# Forward compatibility ./Forward_compatibility
# ./Software_incompatibility Software incompatibility ['mw:WikiLink']
# Software incompatibility ./Software_incompatibility
# ./Data_modeling Data modeling ['mw:WikiLink']
# Data modeling ./Data_modeling
# ./Enterprise_architecture Enterprise architecture ['mw:WikiLink']
# Enterprise architecture ./Enterprise_architecture
# ./Functional_specification Functional specification ['mw:WikiLink']
# Functional specification ./Functional_specification
# ./Modeling_language Modeling language ['mw:WikiLink']
# Modeling language ./Modeling_language
# ./Programming_paradigm Programming paradigm ['mw:WikiLink']
# Programming paradigm ./Programming_paradigm
# ./Software Software ['mw:WikiLink']
# Software ./Software
# ./Software_archaeology Software archaeology ['mw:WikiLink']
# Software archaeology ./Software_archaeology
# ./Software_architecture Software architecture ['mw:WikiLink']
# Software architecture ./Software_architecture
# ./Software_configuration_management Software configuration management ['mw:WikiLink']
# Software configuration management ./Software_configuration_management
# ./Software_development_process Software development process/methodology ['mw:WikiLink']
# Software development process/methodology ./Software_development_process
# ./Software_quality Software quality ['mw:WikiLink']
# Software quality ./Software_quality
# ./Software_quality_assurance Software quality assurance ['mw:WikiLink']
# Software quality assurance ./Software_quality_assurance
# ./Software_verification_and_validation Software verification and validation ['mw:WikiLink']
# Software verification and validation ./Software_verification_and_validation
# ./Software_system Software system ['mw:WikiLink']
# Software system ./Software_system
# ./Structured_analysis Structured analysis ['mw:WikiLink']
# Structured analysis ./Structured_analysis
# ./Essential_systems_analysis Essential analysis ['mw:WikiLink']
# Essential analysis ./Essential_systems_analysis
# ./CI/CD CI/CD ['mw:WikiLink']
# CI/CD ./CI/CD
# ./Agile_software_development Agile ['mw:WikiLink']
# Agile ./Agile_software_development
# ./Aspect-oriented_programming Aspect-oriented ['mw:WikiLink']
# Aspect-oriented ./Aspect-oriented_programming
# ./Object-oriented_programming Object orientation ['mw:WikiLink']
# Object orientation ./Object-oriented_programming
# ./Ontology_(information_science) Ontology ['mw:WikiLink']
# Ontology ./Ontology_(information_science)
# ./Service-oriented_architecture Service orientation ['mw:WikiLink']
# Service orientation ./Service-oriented_architecture
# ./Systems_development_life_cycle SDLC ['mw:WikiLink']
# SDLC ./Systems_development_life_cycle
# ./Agile_software_development Agile ['mw:WikiLink']
# Agile ./Agile_software_development
# ./Enterprise_unified_process EUP ['mw:WikiLink']
# EUP ./Enterprise_unified_process
# ./Executable_UML Executable UML ['mw:WikiLink']
# Executable UML ./Executable_UML
# ./Incremental_build_model Incremental model ['mw:WikiLink']
# Incremental model ./Incremental_build_model
# ./Iterative_and_incremental_development Iterative model ['mw:WikiLink']
# Iterative model ./Iterative_and_incremental_development
# ./Software_prototyping Prototype model ['mw:WikiLink']
# Prototype model ./Software_prototyping
# ./Rapid_application_development RAD ['mw:WikiLink']
# RAD ./Rapid_application_development
# ./Unified_Process UP ['mw:WikiLink']
# UP ./Unified_Process
# ./Scrum_(software_development) Scrum ['mw:WikiLink']
# Scrum ./Scrum_(software_development)
# ./Spiral_model Spiral model ['mw:WikiLink']
# Spiral model ./Spiral_model
# ./V-model_(software_development) V-model ['mw:WikiLink']
# V-model ./V-model_(software_development)
# ./Waterfall_model Waterfall model ['mw:WikiLink']
# Waterfall model ./Waterfall_model
# ./Extreme_programming XP ['mw:WikiLink']
# XP ./Extreme_programming
# ./Model-driven_engineering Model-driven engineering ['mw:WikiLink']
# Model-driven engineering ./Model-driven_engineering
# ./Round-trip_engineering Round-trip engineering ['mw:WikiLink']
# Round-trip engineering ./Round-trip_engineering
# ./ISO/IEC_15504 SPICE ['mw:WikiLink']
# SPICE ./ISO/IEC_15504
# ./Capability_Maturity_Model_Integration CMMI ['mw:WikiLink']
# CMMI ./Capability_Maturity_Model_Integration
# ./Data_model Data model ['mw:WikiLink']
# Data model ./Data_model
# ./Entity–relationship_model ER model ['mw:WikiLink']
# ER model ./Entity–relationship_model
# ./Function_model Function model ['mw:WikiLink']
# Function model ./Function_model
# ./Information_model Information model ['mw:WikiLink']
# Information model ./Information_model
# ./Metamodeling Metamodeling ['mw:WikiLink']
# Metamodeling ./Metamodeling
# ./Object_model Object model ['mw:WikiLink']
# Object model ./Object_model
# ./Systems_modeling Systems model ['mw:WikiLink']
# Systems model ./Systems_modeling
# ./View_model View model ['mw:WikiLink']
# View model ./View_model
# ./IDEF IDEF ['mw:WikiLink']
# IDEF ./IDEF
# ./Unified_Modeling_Language UML ['mw:WikiLink']
# UML ./Unified_Modeling_Language
# ./Universal_Systems_Language USL ['mw:WikiLink']
# USL ./Universal_Systems_Language
# ./Systems_modeling_language SysML ['mw:WikiLink']
# SysML ./Systems_modeling_language
# ./Computer_science Computer science ['mw:WikiLink']
# Computer science ./Computer_science
# ./Computer_engineering Computer engineering ['mw:WikiLink']
# Computer engineering ./Computer_engineering
# ./Information_science Information science ['mw:WikiLink']
# Information science ./Information_science
# ./Project_management Project management ['mw:WikiLink']
# Project management ./Project_management
# ./Risk_management Risk management ['mw:WikiLink']
# Risk management ./Risk_management
# ./Systems_engineering Systems engineering ['mw:WikiLink']
# Systems engineering ./Systems_engineering
# https://commons.wikimedia.org/wiki/Category:Software%20engineering Commons ['mw:WikiLink/Interwiki']
# ./Category:Software_engineering Category ['mw:WikiLink']
# Category ./Category:Software_engineering
# ./Help:Authority_control Authority control databases ['mw:WikiLink']
# Authority control databases ./Help:Authority_control
# https://www.wikidata.org/wiki/Q21198#identifiers  []
# https://d-nb.info/gnd/4026894-9 Germany ['mw:ExtLink', 'nofollow']
# https://id.loc.gov/authorities/sh89003285 United States ['mw:ExtLink', 'nofollow']
# https://catalogue.bnf.fr/ark:/12148/cb11932109b France ['mw:ExtLink', 'nofollow']
# https://data.bnf.fr/ark:/12148/cb11932109b BnF data ['mw:ExtLink', 'nofollow']
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ph124511&CON_LNG=ENG Czech Republic ['mw:ExtLink', 'nofollow']
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX525961 Spain ['mw:ExtLink', 'nofollow']
# https://lod.nl.go.kr/resource/KSH2002030991 Korea ['mw:ExtLink', 'nofollow']
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007549081005171 Israel ['mw:ExtLink', 'nofollow']
# https://hls-dhs-dss.ch/fr/articles/008272 Historical Dictionary of Switzerland ['mw:ExtLink', 'nofollow']
# http://esu.com.ua/search_articles.php?id=12450 Encyclopedia of Modern Ukraine ['mw:ExtLink', 'nofollow']
